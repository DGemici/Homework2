# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np

import nsfg
import first
import thinkstats2
import thinkplot

# %%
a = np.array([1, 2, 3])  # Create a rank 1 array
print(type(a))            # Prints "<type 'numpy.ndarray'>"
print(a.shape)            # Prints "(3,)"
print(a[0], a[1], a[2])   # Prints "1 2 3"
a[0] = 5                 # Change an element of the array
print (a)                  # Prints "[5, 2, 3]"

b = np.array([[1,2,3],[4,5,6]])     # Create a rank 2 array
print (b.shape)                     # Prints "(2, 3)"
print (b[0, 0], b[0, 1], b[1, 0])   # Prints "1 2 4"
# Out:
# <type 'numpy.ndarray'>
# (3L,)
# 1 2 3
# [5 2 3]
# (2L, 3L)
# 1 2 4

# %%
#question 1
preg = nsfg.ReadFemResp()
preg
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0       2298        1         5         5            1          5.0     27
# 1       5012        1         5         1            5          5.0     42
# 2      11586        1         5         1            5          5.0     43
# 3       6794        5         5         4            1          5.0     15
# 4        616        1         5         4            1          5.0     20
# 5        845        1         5         4            1          5.0     42
# 6      10333        5         5         3            1          5.0     17
# 7        855        5         5         4            5          5.0     22
# 8       8656        5         5         4            1          5.0     38
# 9       3566        5         5         4            5          5.0     21
# 10      5917        1         5         3            1          5.0     44
# ...

# %%
preg.fmar1age
# Out:
# 0        NaN
# 1       21.0
# 2       16.0
# 3        NaN
# 4        NaN
# 5       17.0
# 6        NaN
# 7        NaN
# 8       18.0
# 9        NaN
# 10      19.0
# 11      25.0
# 12      23.0
# 13      16.0
# 14      14.0
# 15       NaN
# 16      17.0
# 17      30.0
# 18       NaN
# 19      16.0
# 20       NaN
# 21      18.0
# 22      24.0
# 23      24.0
# 24      27.0
# 25       NaN
# 26       NaN
# 27      22.0
# 28      19.0
# 29      19.0
#         ...
# 7613     NaN
# 7614    23.0
# 7615     NaN
# 7616    19.0
# 7617    23.0
# 7618    26.0
# 7619    27.0
# 7620    24.0
# 7621     NaN
# 7622     NaN
# 7623     NaN
# 7624    23.0
# 7625     NaN
# 7626     NaN
# 7627     NaN
# 7628     NaN
# 7629    21.0
# 7630    37.0
# 7631     NaN
# 7632    25.0
# 7633    20.0
# 7634    21.0
# 7635    17.0
# 7636    18.0
# 7637    21.0
# 7638    18.0
# 7639     NaN
# 7640     NaN
# 7641     NaN
# 7642     NaN
# Name: fmar1age, dtype: float64

# %%
hist = thinkstats2.Hist(preg.fmar1age)
hist
for val in sorted(hist.Values()):
    print(val, hist[val])
# Out:
# 9.0 1
# 11.0 2
# 12.0 1
# 13.0 3
# 14.0 18
# 15.0 50
# 16.0 115
# 17.0 173
# 18.0 342
# 19.0 328
# 20.0 353
# 21.0 364
# 22.0 381
# 23.0 359
# 24.0 285
# 25.0 261
# 26.0 233
# 27.0 177
# 28.0 150
# 29.0 129
# 30.0 97
# 31.0 72
# 32.0 52
# 33.0 49
# 34.0 29
# 35.0 35
# 36.0 14
# 37.0 14
# 38.0 10
# 39.0 10
# 40.0 7
# 41.0 6
# 42.0 3
# 43.0 3

# %%
hist = thinkstats2.Hist(preg.fmar1age, label='birth weighht')
#print(hist)
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Ages ', ylabel='Count of getting married')

# %%
#2. question
preg.fmarno
# Out:
# 0       0
# 1       2
# 2       1
# 3       0
# 4       0
# 5       1
# 6       0
# 7       0
# 8       1
# 9       0
# 10      1
# 11      1
# 12      1
# 13      2
# 14      1
# 15      0
# 16      1
# 17      1
# 18      0
# 19      1
# 20      0
# 21      1
# 22      1
# 23      1
# 24      1
# 25      0
# 26      0
# 27      1
# 28      1
# 29      1
#        ..
# 7613    0
# 7614    1
# 7615    0
# 7616    2
# 7617    1
# 7618    1
# 7619    1
# 7620    1
# 7621    0
# 7622    0
# 7623    0
# 7624    1
# 7625    0
# 7626    0
# 7627    0
# 7628    0
# 7629    1
# 7630    1
# 7631    0
# 7632    1
# 7633    1
# 7634    1
# 7635    1
# 7636    1
# 7637    1
# 7638    2
# 7639    0
# 7640    0
# 7641    0
# 7642    0
# Name: fmarno, dtype: int64

# %%
hist2 = thinkstats2.Hist(preg.fmarno)
hist2
for val in sorted(hist2.Values()):
    print(val, hist2[val])
# Out:
# 0 3517
# 1 3436
# 2 582
# 3 90
# 4 15
# 5 3

# %%
hist = thinkstats2.Hist(preg.fmarno, label='birth weighht')
#print(hist)
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Count of mariage ', ylabel='Count of people')

# %%
#4. question

neverMarried = preg[preg.fmarno == 0]
neverMarried
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0       2298        1         5         5            1          5.0     27
# 3       6794        5         5         4            1          5.0     15
# 4        616        1         5         4            1          5.0     20
# 6      10333        5         5         3            1          5.0     17
# 7        855        5         5         4            5          5.0     22
# 9       3566        5         5         4            5          5.0     21
# 15      3697        5         5         4            5          5.0     28
# 18      8542        5         5         5            5          5.0     16
# 20      3719        5         5         2            5          5.0     22
# 25      2178        5         5         3            1          5.0     29
# 26      8358        5         5         4            5          5.0     21
# ...

# %%
married =preg[preg.fmarno>=1]
married
# Out:
#       caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 1       5012        1         5         1            5          5.0     42
# 2      11586        1         5         1            5          5.0     43
# 5        845        1         5         4            1          5.0     42
# 8       8656        5         5         4            1          5.0     38
# 10      5917        1         5         3            1          5.0     44
# 11      9200        5         5         3            1          5.0     26
# 12      6320        5         5         5            5          1.0     23
# 13     11700        1         5         4            1          5.0     34
# 14      7354        1         5         4            1          5.0     28
# 16      4881        1         5         5            1          5.0     23
# 17      5862        1         5         4            1          5.0     33
# ...

# %%
first_hist = thinkstats2.Hist(married.totincr, label='first')
other_hist = thinkstats2.Hist(neverMarried.totincr, label='other')
print(first_hist)
print(other_hist)
# Out:
# Hist({1: 94, 2: 108, 3: 103, 4: 182, 5: 207, 6: 291, 7: 283, 8: 318, 9: 331, 10: 253, 11: 390, 12: 406, 13: 387, 14: 773})
# Hist({1: 205, 2: 193, 3: 163, 4: 239, 5: 238, 6: 268, 7: 300, 8: 288, 9: 276, 10: 215, 11: 257, 12: 252, 13: 236, 14: 387})

# %%
width = 0.45
thinkplot.PrePlot(2)
thinkplot.Hist(first_hist, align='right', width=width)
thinkplot.Hist(other_hist, align='left', width=width)
thinkplot.Config(xlabel='value', ylabel='Total count', xlim=[0, 15])

# %%
#question 5
neverMarried.totincr.mean()
# Out:
# 8.020756326414558

# %%
married.totincr.mean()
# Out:
# 9.495152690256907

# %%
married.totincr.min()
# Out:
# 1

# %%
married.totincr.max()
# Out:
# 14

# %%
neverMarried.totincr.var()
# Out:
# 15.846838676954563

# %%
neverMarried.totincr.min()
# Out:
# 1

# %%
neverMarried.totincr.max()
# Out:
# 14

# %%
neverMarried.totincr.std()
# Out:
# 3.9808087968344528

# %%
married.totincr.std()
# Out:
# 3.71465249580075

# %%
married.totincr.var()
# Out:
# 13.79864316455874
